# %% [markdown]
# # Entrenamiento de expresiones faciales\n\nEste notebook usa el pipeline de la rama `feature/Joshua`. A diferencia del ejemplo binario de Ringa Tech, entrena ocho expresiones con `softmax` y conserva las particiones Train/Validation/Test suministradas.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
      PROJECT_ROOT = PROJECT_ROOT.parent
DATASET_ROOT = Path('/content/dataset_modelo')  # Ajustar a la ubicación extraída del ZIP
assert (DATASET_ROOT / 'Train').is_dir(), 'Configura DATASET_ROOT antes de continuar.'
PROJECT_ROOT, DATASET_ROOT

# %%
# En Colab o un entorno nuevo, instalar dependencias una sola vez.\n# !{sys.executable} -m pip install -r {PROJECT_ROOT / 'requirements.txt'}

# %%
import subprocess

command = [
        sys.executable, str(PROJECT_ROOT / 'src' / 'train_expression_classifier.py'),
        '--data-dir', str(DATASET_ROOT),
        '--output-dir', str(PROJECT_ROOT / 'artifacts' / 'expressions'),
        '--export-tflite',
        ]
subprocess.run(command, check=True)

# %%
from google.colab import drive
drive.mount("/content/drive")

# !git clone --branch feature/facial-expression-recognition \
  https://github.com/Niot-Espol/facetracker.git /content/facetracker

# %cd /content/facetracker
# !pip install -q -r requirements.txt
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_453/109584063.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive")
#       3
#       4 get_ipython().system('git clone --branch feature/facial-expression-recognition    https://github.com/Niot-Espol/facetracker.git /content/facetracker')
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
